# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread("images\samoyed_puppy_dog_pictures.jpg")

# Create a window to display the image
cv2.namedWindow("Image")

# Create a slider to adjust the temperature of the image
cv2.createTrackbar("Temperature", "Image", 0, 100, lambda x: x)

while True:
    # Convert the image to the HSV color space
    image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get the value of the temperature slider
    temperature = cv2.getTrackbarPos("Temperature", "Image")
    temperature = temperature / 100.0
    # Adjust the temperature of the image by changing the value of the H channel
    # image_hsv[:,:,2] = image_hsv[:,:,2] + temperature
    image_hsv[:, :, 0] = image_hsv[:, :, 0] * temperature
    image_hsv[:, :, 2] = image_hsv[:, :, 2] * (1.0 - temperature)

    # Convert the image back to the BGR color space
    image_edited = cv2.cvtColor(image_hsv, cv2.COLOR_RGB2BGR)

    # Display the edited image
    cv2.imshow("Image", image_edited)

    # Check for user input
    key = cv2.waitKey(1)
    if key == 27: # Esc key
        break

# Save the edited image
cv2.imwrite("output.jpg", image_edited)

# Destroy the window
cv2.destroyAllWindows()

# %%
from PIL import Image, ImageEnhance

#read the image
im = Image.open("landscape.jpg")

#image brightness enhancer
enhancer = ImageEnhance.Contrast(im)

factor = 1.5 #gives original image
im_output = enhancer.enhance(factor)
im_output.show()

# %%
import cv2
import numpy as np
from PIL import Image, ImageEnhance
from skimage import exposure

# Load the image
image = cv2.imread("images\samoyed_puppy_dog_pictures.jpg")
# image = Image.open("samoyed_puppy_dog_pictures.jpg")
# Create a window to display the image
cv2.namedWindow("Image")

# Create a slider to adjust the temperature of the image
cv2.createTrackbar("Temperature", "Image", 40, 100, lambda x: x)

while True:
    # Convert the image to the HSV color space
    # image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # enhancer = ImageEnhance.Contrast(image)
    # Get the value of the temperature slider
    temperature = cv2.getTrackbarPos("Temperature", "Image")
    # temperature = temperature / 200
    # Adjust the temperature of the image by changing the value of the H channel
    # image_hsv[:,:,2] = image_hsv[:,:,2] + temperature
    # image_hsv[:, :, 0] = image_hsv[:, :, 0] * temperature
    # image_hsv[:, :, 2] = image_hsv[:, :, 2] * (1.0 - temperature)

    # Convert the image back to the BGR color space
    # enhancer = ImageEnhance.Contrast(image) # contrast
    # enhancer = ImageEnhance.Brightness(image) # brightness
    # enhancer = ImageEnhance.Sharpness(image) # độ sắc nét
    # enhancer = ImageEnhance.Color(image) # độ bão hòa, saturation
    


    # im_output = enhancer.enhance(temperature)
    # im_output = np.array(im_output)
    # image_edited = cv2.cvtColor(im_output, cv2.COLOR_RGB2BGR)

    # image = image.astype(np.float64)
    gamma = temperature / 10000
    print(gamma)
    bright_image = image * gamma
    # corrected_image = np.clip(corrected_image*255, 0, 255).astype(np.uint8)


    # Display the edited image
    cv2.imshow("Image", bright_image)

    # Check for user input
    key = cv2.waitKey(1)
    if key == 27: # Esc key
        break

# Save the edited image
# cv2.imwrite("output.jpg", image_edited)

# Destroy the window
cv2.destroyAllWindows()
# Out:
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# 0.004
# ...

# %%
a = (1,1,2,3)
len(a)
# Out:
# 4

# %%
x.a1
# Out:
# 1
